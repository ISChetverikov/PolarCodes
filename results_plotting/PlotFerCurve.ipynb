# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

scl1_df = pd.read_csv("..//results//SCL1.results", skipinitialspace=True, sep=',', comment='#')
scl2_df = pd.read_csv("..//results//SCL2.results", skipinitialspace=True, sep=',', comment='#')
scl4_df = pd.read_csv("..//results//SCL4.results", skipinitialspace=True, sep=',', comment='#')
scl8_df = pd.read_csv("..//results//SCL8.results", skipinitialspace=True, sep=',', comment='#')
scl16_df = pd.read_csv("..//results//SCL16.results", skipinitialspace=True, sep=',', comment='#')
scl32_df = pd.read_csv("..//results//SCL32.results", skipinitialspace=True, sep=',', comment='#')
scf1_df = pd.read_csv("..//results//SCFLIPPROG_488_level1_.results", skipinitialspace=True, sep=',', comment='#')
scf2_df = pd.read_csv("..//results//SCFLIPPROG_488_level2_copy.results", skipinitialspace=True, sep=',', comment='#')
scf3_df = pd.read_csv("..//results//SCFLIPPROG_488_level3_.results", skipinitialspace=True, sep=',', comment='#')
scf4_df = pd.read_csv("..//results//SCFLIPPROG_488_level4_clean_last.results", skipinitialspace=True, sep=',', comment='#')

snr = scl1_df['SNR']
scl1 = scl1_df['FER']
scl2 = scl2_df['FER']
scl4 = scl4_df['FER']
scl8 = scl8_df['FER']
snr_l8 = scl8_df['SNR']

scl16 = scl16_df['FER']
snr_l16 = scl16_df['SNR']

scl32 = scl32_df['FER']
snr_l32 = scl32_df['SNR']

scf1 = scf1_df['FER']
scf2 = scf2_df['FER']
scf3 = scf3_df['FER']
scf4 = scf4_df['FER']
snr_f4 = scf4_df['SNR']

plt.figure(figsize=(10,8))
plt.plot(snr, scl1, snr, scl2, snr, scl4, snr_l8, scl8, snr_l16, scl16, snr_l32,scl32,snr, scf1,snr, scf2, snr, scf3);
plt.title("SC vs SCFlip")
plt.legend(["SC", "SCL2", "SCL4", "SCL8", "SCL16", "SCL32","SCFlipProgLevel1","SCFlipProgLevel2","SCFlipProgLevel3","SCFlipProgLevel4"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("ScVsScFanoNew.png");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d5bc30dde51d> in <module>
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4
# ----> 5 scl1_df = pd.read_csv("..//results//SCL1.results", skipinitialspace=True, sep=',', comment='#')
#       6 scl2_df = pd.read_csv("..//results//SCL2.results", skipinitialspace=True, sep=',', comment='#')
#       7 scl4_df = pd.read_csv("..//results//SCL4.results", skipinitialspace=True, sep=',', comment='#')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ..//results//SCL1.results does not exist: '..//results//SCL1.results'

# %%
scf3

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

scl1_df = pd.read_csv("..//results//scl1.results", skipinitialspace=True, sep=',', comment='#')
scl2_df = pd.read_csv("..//results//scl2.results", skipinitialspace=True, sep=',', comment='#')
scl4_df = pd.read_csv("..//results//scl4.results", skipinitialspace=True, sep=',', comment='#')
scl8_df = pd.read_csv("..//results//scl8.results", skipinitialspace=True, sep=',', comment='#')
scl16_df = pd.read_csv("..//results//scl16.results", skipinitialspace=True, sep=',', comment='#')
scl32_df = pd.read_csv("..//results//scl32.results", skipinitialspace=True, sep=',', comment='#')
scf_df = pd.read_csv("..//results//test6.results", skipinitialspace=True, sep=',', comment='#')
scfs_df = pd.read_csv("..//results//flipstatsingle.results", skipinitialspace=True, sep=',', comment='#')

scfss_df = pd.read_csv("..//results//flipstatsingle20.results", skipinitialspace=True, sep=',', comment='#')
scfsd_df = pd.read_csv("..//results//flipstatdouble20.results", skipinitialspace=True, sep=',', comment='#')
scfsm_df = pd.read_csv("..//results//flipstatmixed1010.results", skipinitialspace=True, sep=',', comment='#')

snr = scl1_df['SNR']
scl1 = scl1_df['FER']
scl2 = scl2_df['FER']
scl4 = scl4_df['FER']
scl8 = scl8_df['FER']
scl16 = scl16_df['FER']
scl32 = scl32_df['FER']

scf = scf_df['FER']
scfs = scfs_df['FER']

scfss = scfss_df['FER']
scfsd = scfsd_df['FER']
scfsm = scfsm_df['FER']

plt.figure(figsize=(10,8))
plt.plot(snr, scl1, snr, scl2, snr, scl4, snr, scl8, snr, scl16, snr, scl32, snr, scf, snr, scfs, snr, scfss, snr, scfsd, snr, scfsm);
plt.title("SCL vs SCFlipStat")
plt.legend(["SC", "SCL2", "SCL4", "SCL8", "SCL16", "SCL32", "SCFlipStatDouble", "SCFlipStatSingle", "SCFlipStatSingle20", "SCFlipStatDouble20", "SCFlipStatMixed1010"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("SclVsScFlipStat.png");

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

scl1_df = pd.read_csv("..//results//128//scl1_128_64.results", skipinitialspace=True, sep=',', comment='#')
scl2_df = pd.read_csv("..//results//128//scl2_128_64.results", skipinitialspace=True, sep=',', comment='#')
scl4_df = pd.read_csv("..//results//128//scl4_128_64.results", skipinitialspace=True, sep=',', comment='#')
scl8_df = pd.read_csv("..//results//128//scl8_128_64.results", skipinitialspace=True, sep=',', comment='#')
scl16_df = pd.read_csv("..//results//128//scl16_128_64.results", skipinitialspace=True, sep=',', comment='#')
scl32_df = pd.read_csv("..//results//128//scl32_128_64.results", skipinitialspace=True, sep=',', comment='#')
scfs20_df = pd.read_csv("..//results//128//flipstat_128_20single.results", skipinitialspace=True, sep=',', comment='#')
scfs1010_df = pd.read_csv("..//results//128//flipstat_128_1010mixed.results", skipinitialspace=True, sep=',', comment='#')
scfs1_df = pd.read_csv("..//results//128//flipstat_128_level1.results", skipinitialspace=True, sep=',', comment='#')
scfs2_df = pd.read_csv("..//results//128//flipstat_128_level2.results", skipinitialspace=True, sep=',', comment='#')

snr = scl1_df['SNR']
scl1 = scl1_df['FER']
scl2 = scl2_df['FER']
scl4 = scl4_df['FER']
scl8 = scl8_df['FER']
scl16 = scl16_df['FER']
scl32 = scl32_df['FER']
s = scl32_df['SNR']
scfs20 = scfs20_df['FER']
scfs1010 = scfs1010_df['FER']
scfs1 = scfs1_df['FER']
scfs2 = scfs2_df['FER']

plt.figure(figsize=(10,8))
plt.plot(snr, scl1, snr, scl2, snr, scl4, snr, scl8, snr, scl16, s, scl32, snr, scfs2, snr, scfs1, snr, scfs20, snr, scfs1010);
plt.title("SCL vs SCFlipStat")
plt.legend(["SC", "SCL2", "SCL4", "SCL8", "SCL16", "SCL32", "SCFlipStatDouble", "SCFlipStatSingle", "SCFlipStatSingle20", "SCFlipStatMixed1010"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("ScVsScFano128.png");

# %%
scl8_df = pd.read_csv("..//results//256//scl8.results", skipinitialspace=True, sep=',', comment='#')
scl16_df = pd.read_csv("..//results//256//scl16.results", skipinitialspace=True, sep=',', comment='#')
scl32_df = pd.read_csv("..//results//256//scl32.results", skipinitialspace=True, sep=',', comment='#')

sclf20_df = pd.read_csv("..//results//256//SCLFlip20.results", skipinitialspace=True, sep=',', comment='#')
sclf40_df = pd.read_csv("..//results//256//SCLFlip40.results", skipinitialspace=True, sep=',', comment='#')
sclft20_df = pd.read_csv("..//results//256//TSCLFlip20.results", skipinitialspace=True, sep=',', comment='#')
sclft40_df = pd.read_csv("..//results//256//TSCLFlip40.results", skipinitialspace=True, sep=',', comment='#')

sco1_df = pd.read_csv("..//results//256//oracle_test.results", skipinitialspace=True, sep=',', comment='#')
sco2_df = pd.read_csv("..//results//256//oracle_level2_test.results", skipinitialspace=True, sep=',', comment='#')

snr = scl8_df['SNR']
scl8 = scl8_df['FER']
scl16 = scl16_df['FER']
scl32 = scl32_df['FER']

sclf20 = sclf20_df['FER']
sclf40 = sclf40_df['FER']
sclft20 = sclft20_df['FER']
sclft40 = sclft40_df['FER']

sco1 = sco1_df['FER']
sco2 = sco2_df['FER']

plt.figure(figsize=(10,8))
plt.plot(snr, scl8, snr, scl16, snr, scl32, snr, sclf20, snr, sclf40, snr, sclft20, snr, sclft40);
plt.title("SCL vs SCL-Flip vs TSCL-Flip")
plt.legend(["SCL8", "SCL16", "SCL32", "SCL8-Flip-20", "SCL8-Flip-40", "TSCL8-Flip-20", "TSCL8-Flip-40", "SCL-Oracle-1", "SCL-Oracle-2"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("SclVsSCFlip.png");

# %%
scl8_df = pd.read_csv("..//results//256//scl8.results", skipinitialspace=True, sep=',', comment='#')
scl16_df = pd.read_csv("..//results//256//scl16.results", skipinitialspace=True, sep=',', comment='#')
scl32_df = pd.read_csv("..//results//256//scl32.results", skipinitialspace=True, sep=',', comment='#')

sclf20_df = pd.read_csv("..//results//256//SCLFlip20.results", skipinitialspace=True, sep=',', comment='#')
sclf40_df = pd.read_csv("..//results//256//SCLFlip40.results", skipinitialspace=True, sep=',', comment='#')
sclft20_df = pd.read_csv("..//results//256//TSCLFlip20.results", skipinitialspace=True, sep=',', comment='#')
sclft40_df = pd.read_csv("..//results//256//TSCLFlip40.results", skipinitialspace=True, sep=',', comment='#')

sco1_df = pd.read_csv("..//results//256//oracle_test.results", skipinitialspace=True, sep=',', comment='#')
sco2_df = pd.read_csv("..//results//256//oracle_level2_test.results", skipinitialspace=True, sep=',', comment='#')

snr = scl8_df['SNR']
scl8 = scl8_df['FER']

sco1 = sco1_df['FER']
sco2 = sco2_df['FER']

plt.figure(figsize=(10,8))
plt.plot(snr, scl8, snr, sco1, snr, sco2);
plt.title("SCL vs SCL Oracle Flip")
plt.legend(["SCL8", "SCL8-Oracle-1", "SCL8-Oracle-2"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("SclVsSCFlip.png");

# %%
sc_df = pd.read_csv("..//results//128//sc_without_crc.results", skipinitialspace=True, sep=',', comment='#')
scc_df = pd.read_csv("..//results//128//sc_wiht_crc.results", skipinitialspace=True, sep=',', comment='#')

scl2_df = pd.read_csv("..//results//128//scl2.results", skipinitialspace=True, sep=',', comment='#')
scl4_df = pd.read_csv("..//results//128//scl4.results", skipinitialspace=True, sep=',', comment='#')

snr = sc_df['SNR']
sc = sc_df['FER']
scc = scc_df['FER']
scl2 = scl2_df['FER']
scl4 = scl4_df['FER']

plt.figure(figsize=(10,8))
plt.plot(snr, sc, snr, scc, snr, scl2, snr, scl4);
plt.title("SC vs SC CRC aided (128, 56), CRC - 8 bit")
plt.legend(["SC", "SC-CRC-aided", "SCL2", "SCL4"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("SCVsSCC.png");

# %%
sc_df = pd.read_csv("..//results//128//scfano_without_crc.results", skipinitialspace=True, sep=',', comment='#')
scc_df = pd.read_csv("..//results//128//scfano_with_crc.results", skipinitialspace=True, sep=',', comment='#')

scl2_df = pd.read_csv("..//results//128//scl2.results", skipinitialspace=True, sep=',', comment='#')
scl4_df = pd.read_csv("..//results//128//scl4.results", skipinitialspace=True, sep=',', comment='#')

scf2_df = pd.read_csv("..//results//128//sclfano2.results", skipinitialspace=True, sep=',', comment='#')
scf4_df = pd.read_csv("..//results//128//sclfano4.results", skipinitialspace=True, sep=',', comment='#')

snr = sc_df['SNR']
sc = sc_df['FER']
scc = scc_df['FER']
scl2 = scl2_df['FER']
scl4 = scl4_df['FER']

scf2 = scf2_df['FER']
scf4 = scf4_df['FER']

plt.figure(figsize=(10,8))
plt.plot(snr, sc, snr, scc, snr, scl2, snr, scl4, snr, scf2, snr, scf4);
plt.title("SC vs SC CRC aided (128, 56), CRC - 8 bit")
plt.legend(["SC Fano", "SC-Fano-CRC-aided", "SCL2", "SCL4", "SCFanoFlip2", "SCFanoFlip4"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("SCFanoVsSCCFano.png");

# %%
sc_df = pd.read_csv("..//results//128//sc_without_crc.results", skipinitialspace=True, sep=',', comment='#')
sclf_df = pd.read_csv("..//results//128//sclfano8_delta51test1.results", skipinitialspace=True, sep=',', comment='#')
scl4_df = pd.read_csv("..//results//128//scl4.results", skipinitialspace=True, sep=',', comment='#')

snr = sc_df['EbN0']
sc = sc_df['FER']
sclf = sclf_df['FER']
scl4 = scl4_df['FER']

plt.figure(figsize=(10,8))
plt.plot(snr, sc, snr, sclf, snr, scl4);
plt.title("SCL4 vs SCFF (128, 56), CRC - 8 bit")
plt.legend(["SC", "SCFanoFlip(T=8,delta=5)", "SCL4"])
plt.xlabel("EbN0")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("SCVsSCC.png");

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

a_df = pd.read_csv("..//results//128//awgn.results", skipinitialspace=True, sep=',', comment='#')
b_df = pd.read_csv("..//results//128//bsc.results", skipinitialspace=True, sep=',', comment='#')


a_snr = a_df['SNR']
b_snr = b_df['SNR']
a = a_df['FER']
b = b_df['FER']

plt.figure(figsize=(10,8))
plt.plot(a_snr, a, b_snr, b)
plt.title("AWGN vs BSC (128, 56)")
plt.legend(["AWGN", "BSC"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("AWGNvsBSC.png");

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

a_df = pd.read_csv("..//results//128//SC.results", skipinitialspace=True, sep=',', comment='#')
b_df = pd.read_csv("..//results//128//SCL_4.results", skipinitialspace=True, sep=',', comment='#')
#c_df = pd.read_csv("..//results//128//SCS_no_512.results", skipinitialspace=True, sep=',', comment='#')
#d_df = pd.read_csv("..//results//128//SCS_no_256.results", skipinitialspace=True, sep=',', comment='#')
e_df = pd.read_csv("..//results//128//SCS_4_512.results", skipinitialspace=True, sep=',', comment='#')



a_snr = a_df['SNR']
b_snr = b_df['SNR']
#c_snr = c_df['SNR']
#d_snr = d_df['SNR']
e_snr = e_df['SNR']

a = a_df['FER']
b = b_df['FER']
#c = c_df['FER']
#d = d_df['FER']
e = e_df['FER']


plt.figure(figsize=(10,8))
plt.plot(a_snr, a, b_snr, b, e_snr, e)
plt.title("SC, SCL vs SCS")
plt.legend(["SC", "SCL4", "SCS4_512", "SCS_256", "SCS_4_512"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("SCvsSCS.png");

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

snr = [0.08, 0.067, 0.056, 0.046, 0.037, 0.029, 0.022, 0.017]
a = [0.34, 0.21, 0.11, 0.05, 0.02, 0.008, 0.0022, 0.0008]
b = [0.2, 0.13, 0.05, 0.02, 0.008, 0.0022, 0.0005, 0.0002]
c1 = [0.19, 0.12, 0.044, 0.018, 0.007, 0.0017, 0.0004, 0.0002]
c5 = [0.215, 0.14, 0.06, 0.02, 0.0085, 0.0023, 0.00054, 0.00021]
c10 = [0.23, 0.15, 0.069, 0.029, 0.009, 0.0029, 0.00068, 0.00030]
plt.figure(figsize=(10,8))
plt.plot(snr, a, marker='x')
plt.plot(snr, b, marker='^')
plt.plot(snr, c1, marker='o')
plt.plot(snr, c5, marker='<')
plt.plot(snr, c10, marker='>')
#plt.title("5G seq vs stat (1024, 488 + 24), SCL32 decoder ")
plt.legend(["SC", "SCL, L=4", "SC-Fano, d=1", "SC-Fano, d=5", "SC-Fano, d=10"], fontsize=15)
plt.xlabel("crossover probability p", fontsize=20)
plt.grid(True)
plt.ylabel("frame error rate", fontsize=20)
plt.yscale('log')
plt.savefig("PropFER.png");

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

snr = [0.08, 0.067, 0.056, 0.046, 0.037, 0.029, 0.022, 0.017]
a = [1, 1, 1, 1, 1, 1, 1, 1]
b = [4, 4, 4, 4, 4, 4, 4, 4]
c1 = [9.3, 4.6, 2.9, 2.5, 2, 1.8, 1.5, 1.2]
c5 = [5.1, 3.8, 2.4, 1.8, 1.54, 1.22, 1.1, 1.01]
c10 = [2.11, 1.72, 1.42, 1.2, 1.045, 1.03, 1.02, 1.0]
plt.figure(figsize=(10,8))
plt.plot(snr, a, marker='x')
plt.plot(snr, b, marker='^')
plt.plot(snr, c1, marker='o')
plt.plot(snr, c5, marker='<')
plt.plot(snr, c10, marker='>')
#plt.title("5G seq vs stat (1024, 488 + 24), SCL32 decoder ")
plt.legend(["SC", "SCL, L=4", "SC-Fano, d=1", "SC-Fano, d=5", "SC-Fano, d=10"], fontsize=15)
plt.xlabel("crossover probability p", fontsize=20)
plt.grid(True)
plt.ylabel("normilized complexity",  fontsize=20)
plt.savefig("PropNC.png");

# %%
scs1 = pd.read_csv("..//results//256//op_128.results", skipinitialspace=True, sep=',', comment='#')
scs2 = pd.read_csv("..//results//512//op_256.results", skipinitialspace=True, sep=',', comment='#')
scs3 = pd.read_csv("..//results//1024//op_512.results", skipinitialspace=True, sep=',', comment='#')
scs4 = pd.read_csv("..//results//1024//op_205.results", skipinitialspace=True, sep=',', comment='#')

scs1.index = ["SCS(256,128+16)"]

scs = pd.concat([scs1, scs2, scs3, scs4])
scs.index = ["SCS(256,128+16)","SCS(512,256+16)","SCS(1024,512+16)","SCS(1024,205+16)"]
scs
# Out:
#                   SNR     EbN0     sigma   FER  rejectionsCount  testsCount  \
# SCS(256,128+16)    -1  2.01030  0.793387  0.00                0         100
# SCS(512,256+16)    -1  2.01030  0.793387  0.01                1         100
# SCS(1024,512+16)   -1  2.01030  0.793387  0.00                0          10
# SCS(1024,205+16)   -5  1.98546  1.257430  0.00                0          10
#
#                   time(ms)       sums       muls     comps       xors  \
# SCS(256,128+16)       1714    7601.71    49.1389   15566.5    44.3746
# SCS(512,256+16)      10098   40148.90   277.4050   81264.0   295.1860
# SCS(1024,512+16)      6138  252727.00  1732.9900  506332.0  2207.5400
# SCS(1024,205+16)      5145  239728.00  2289.2600  459409.0  5387.3900
#
#                      total     iter
# SCS(256,128+16)    23261.7  3.48133
# SCS(512,256+16)   121985.0  4.58627
# SCS(1024,512+16)  762999.0  7.20205
# SCS(1024,205+16)  706814.0  6.55605

# %%
a_df = pd.read_csv("..//results//128//sc.results", skipinitialspace=True, sep=',', comment='#')
b_df = pd.read_csv("..//results//128//scc1.results", skipinitialspace=True, sep=',', comment='#')
c_df = pd.read_csv("..//results//128//scfano.results", skipinitialspace=True, sep=',', comment='#')
#d_df = pd.read_csv("..//results//128//scl4.results", skipinitialspace=True, sep=',', comment='#')
e_df = pd.read_csv("..//results//128//scl8.results", skipinitialspace=True, sep=',', comment='#')

x ='EbN0'

a_snr = a_df[x]
b_snr = b_df[x]
c_snr = c_df[x]
#d_snr = d_df[x]
e_snr = e_df[x]

y='FER'

a = a_df[y]
b = b_df[y]
c = c_df[y]
#d = d_df[y]
e = e_df[y]

plt.figure(figsize=(10,8))
plt.plot(a_snr, a, marker='x')
plt.plot(b_snr, b, marker='^')
plt.plot(c_snr, c, marker='o')
#plt.plot(d_snr, d, marker='<')
plt.plot(e_snr, e, marker='>')
plt.title("Error correcting performance of comparable decoders for PC(128, 64)", fontsize=17)
plt.legend(["SC", "SC-Creeper, Δ=1",  "SC-Fano, Δ=1", "SCL, L=8"], fontsize=15)
plt.xlabel("Eb/N0, dB", fontsize=15)
plt.grid(True)
plt.ylabel("Frame Error Rate, FER",  fontsize=15)
plt.yscale('log')
plt.savefig("z1.png");
#"SC-Fano, d=1", "SC-Fano, d=5", "SC-Fano, d=10"

# %%
a_df = pd.read_csv("..//results//128//sc.results", skipinitialspace=True, sep=',', comment='#')
b_df = pd.read_csv("..//results//128//scc1.results", skipinitialspace=True, sep=',', comment='#')
c_df = pd.read_csv("..//results//128//scfano.results", skipinitialspace=True, sep=',', comment='#')
d_df = pd.read_csv("..//results//128//scl8.results", skipinitialspace=True, sep=',', comment='#')
e_df = pd.read_csv("..//results//128//scl4.results", skipinitialspace=True, sep=',', comment='#')
f_df = pd.read_csv("..//results//128//scs8.results", skipinitialspace=True, sep=',', comment='#')
g_df = pd.read_csv("..//results//128//scs4.results", skipinitialspace=True, sep=',', comment='#')

x ='EbN0'

a_snr = a_df[x]
b_snr = b_df[x]
c_snr = c_df[x]
d_snr = d_df[x]
e_snr = e_df[x]
f_snr = f_df[x]
g_snr = g_df[x]

y='iter'

a = a_df[y]
b = b_df[y]
c = c_df[y]
d = d_df[y]
e = e_df[y]
f = f_df[y]
g = g_df[y]

plt.figure(figsize=(10,8))
plt.plot(a_snr, a, marker='x')
plt.plot(b_snr, b, marker='^')
plt.plot(c_snr, c, marker='o')
plt.plot(d_snr, d, marker='<')
plt.plot(e_snr, e, marker='>')
plt.plot(f_snr, f, marker='s')
plt.plot(g_snr, g, marker='p')

plt.title("Normalized complexity of comparable decoders for PC(128, 64)", fontsize=17)
plt.legend(["SC", "SC-Creeper, Δ=1","SC-Fano, Δ=1", "SCL, L=8", "SCL, L=4", "SCS, L=8, D=1024", "SCS, L=4, D=512"], fontsize=15)
plt.xlabel("Eb/N0, dB", fontsize=15)
plt.grid(True)
plt.ylabel("Normalized complexity", fontsize=15)
#plt.yscale('log')
plt.savefig("z2.png");
#"SC-Fano, d=1", "SC-Fano, d=5", "SC-Fano, d=10"
