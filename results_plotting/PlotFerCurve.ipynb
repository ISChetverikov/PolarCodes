# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

scl1_df = pd.read_csv("..//results//SCL1.results", skipinitialspace=True, sep=',', comment='#')
scl2_df = pd.read_csv("..//results//SCL2.results", skipinitialspace=True, sep=',', comment='#')
scl4_df = pd.read_csv("..//results//SCL4.results", skipinitialspace=True, sep=',', comment='#')
scf1_df = pd.read_csv("..//results//SCFLIPPROG_488_level1_.results", skipinitialspace=True, sep=',', comment='#')
scf2_df = pd.read_csv("..//results//SCFLIPPROG_488_level2_.results", skipinitialspace=True, sep=',', comment='#')

snr = scl1_df['SNR']
scl1 = scl1_df['FER']
scl2 = scl2_df['FER']
scl4 = scl4_df['FER']
scf1 = scf1_df['FER']
scf2 = scf2_df['FER']


plt.figure(figsize=(10,8))
plt.plot(snr, scl1, snr, scl2, snr, scl4, snr, scf1,snr, scf2);
plt.title("SC vs SCFlip")
plt.legend(["SC", "SCL2", "SCL4", "SCFlipProgLevel1","SCFlipProgLevel2"])
plt.xlabel("SNR")
plt.grid(True)
plt.ylabel("FER")
plt.yscale('log')
plt.savefig("ScVsScFanoNew.png");

# %%
scl4
# Out:
# 0    0.267700
# 1    0.039600
# 2    0.002340
# 3    0.000083
# 4    0.000003
# Name: FER, dtype: float64
